# %%
import pandas as pd

feature_df = pd.read_csv("featureDf_170526.csv")

feature_df.isna().sum().sort_values(ascending=False)
# Out:
# error_message        1945
# sp_hsv_std_s            2
# sp_hsv_std_h            2
# sp_hsv_std_v            2
# hsv_mean_h              0
# img_id                  0
# hsv_std_s               0
# hsv_std_h               0
# hsv_mean_v              0
# hsv_mean_s              0
# hsv_std_v               0
# rel_hsv_diff_h          0
# rel_hsv_diff_v          0
# rel_hsv_diff_s          0
# symmetry                0
# border                  0
# diameter                0
# processing_status       0
# dtype: int64

# %%
nan_cols = ["sp_hsv_std_h", "sp_hsv_std_s", "sp_hsv_std_v"]

rows_with_nan = feature_df[feature_df[nan_cols].isna().any(axis=1)]

rows_with_nan[["img_id"] + nan_cols]
rows_with_nan[["img_id", "processing_status", "error_message"]]
# Out:
#                    img_id processing_status  error_message
# 51   PAT_868_1657_698.png           success            NaN
# 511  PAT_753_1428_451.png           success            NaN

# %%
import matplotlib.pyplot as plt

problem_ids = rows_with_nan["img_id"].tolist()
problem_ids
for img_id in problem_ids:
    mask, img = load_and_preprocess(img_id, config)

    plt.figure(figsize=(8, 4))

    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title(img_id)
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(mask, cmap="gray")
    plt.title(f"Mask area: {mask.sum()}")
    plt.axis("off")

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 problem_ids
#       5 for img_id in problem_ids:
# ----> 6     mask, img = load_and_preprocess(img_id, config)
#       8     plt.figure(figsize=(8, 4))
#      10     plt.subplot(1, 2, 1)
#
# NameError: name 'load_and_preprocess' is not defined

# %%
from featureExt_optimized import Config, load_and_preprocess
config = Config(data_dir="../data", max_dim=256)
import matplotlib.pyplot as plt

problem_ids = rows_with_nan["img_id"].tolist()

for img_id in problem_ids:
    mask, img = load_and_preprocess(img_id, config)

    plt.figure(figsize=(8, 4))

    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title(img_id)
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(mask, cmap="gray")
    plt.title(f"Mask area: {mask.sum()}")
    plt.axis("off")

    plt.show()
config = Config(data_dir="../data", max_dim=256)
