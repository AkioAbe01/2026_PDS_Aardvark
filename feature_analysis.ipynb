# %% [markdown]
# # Feature Analysis

# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data (extended)
df_extended = pd.read_csv('src/featureDF_extended.csv')

# keep only features cols
df_extended.drop(['processing_status', 'error_message'], inplace = True)

print('='*60)
print('no. cols')
print('='*60)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       2 df_extended = pd.read_csv('src/featureDF_extended.csv')
#       4 # keep only features cols
# ----> 5 df_extended.drop(['processing_status', 'error_message'], inplace = True)
#       7 print('='*60)
#       8 print('no. cols')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)
#    6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)
#    6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
# ...

# %%
df_extended
# Out:
#                      img_id  hsv_mean_h  hsv_mean_s  hsv_mean_v  hsv_std_h  \
# 0     PAT_1516_1765_530.png    0.596813    0.721711    0.562222   0.006292
# 1        PAT_46_881_939.png    0.744147    0.143894    0.699154   0.054320
# 2     PAT_1545_1867_547.png    0.705389    0.169257    0.919523   0.035141
# 3     PAT_1989_4061_934.png    0.646455    0.214990    0.608748   0.027248
# 4      PAT_684_1302_588.png    0.669913    0.396890    0.527158   0.015138
# ...                     ...         ...         ...         ...        ...
# 1940    PAT_386_785_536.png    0.572169    0.361423    0.512538   0.035448
# 1941    PAT_273_421_905.png    0.650176    0.628007    0.647141   0.010064
# 1942     PAT_491_934_46.png    0.632516    0.387129    0.773343   0.014211
# 1943     PAT_46_880_140.png    0.709280    0.166227    0.738225   0.041577
# 1944    PAT_326_690_823.png    0.662955    0.382170    0.700245   0.020406
#
# ...

# %%
df_extended.isna().sum()
# Out:
# img_id                  0
# hsv_mean_h              0
# hsv_mean_s              0
# hsv_mean_v              0
# hsv_std_h               0
# hsv_std_s               0
# hsv_std_v               0
# sp_hsv_std_h            2
# sp_hsv_std_s            2
# sp_hsv_std_v            2
# rel_hsv_diff_h          0
# rel_hsv_diff_s          0
# rel_hsv_diff_v          0
# symmetry                0
# border                  0
# diameter                0
# processing_status       0
# error_message        1945
# dtype: int64

# %%
df_extended
# Out:
#                      img_id  hsv_mean_h  hsv_mean_s  hsv_mean_v  hsv_std_h  \
# 0     PAT_1516_1765_530.png    0.596813    0.721711    0.562222   0.006292
# 1        PAT_46_881_939.png    0.744147    0.143894    0.699154   0.054320
# 2     PAT_1545_1867_547.png    0.705389    0.169257    0.919523   0.035141
# 3     PAT_1989_4061_934.png    0.646455    0.214990    0.608748   0.027248
# 4      PAT_684_1302_588.png    0.669913    0.396890    0.527158   0.015138
# ...                     ...         ...         ...         ...        ...
# 1940    PAT_386_785_536.png    0.572169    0.361423    0.512538   0.035448
# 1941    PAT_273_421_905.png    0.650176    0.628007    0.647141   0.010064
# 1942     PAT_491_934_46.png    0.632516    0.387129    0.773343   0.014211
# 1943     PAT_46_880_140.png    0.709280    0.166227    0.738225   0.041577
# 1944    PAT_326_690_823.png    0.662955    0.382170    0.700245   0.020406
#
# ...
